# %% [markdown]
# <a href="https://colab.research.google.com/github/shashankchintu99/semester3-projects/blob/main/deeplearning/assignments/Shashankreddy_HW5_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Part 1: GAN
#
# ## Step1. Load the Fashion MNIST dataset and replace the original dataset used in the demo.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import FashionMNIST

fashionmnist = FashionMNIST(root='data',
              train=True,
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:01<00:00, 17524729.84it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 296253.56it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 5441316.11it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 8724152.32it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %% [markdown]
# ##  we are transforming the pixel values, originally within the range [0, 1], to a new range of [-1, 1]

# %%
# Access the first image and label
img, label = fashionmnist[0]
# Print the label and a small portion of the image
print('Label: ', label)

# Print the minimum and maximum values of the image
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  9
# tensor([[[-1.0000, -1.0000, -1.0000,  0.5137,  0.7882],
#          [-0.9765, -1.0000, -0.9059,  0.7176,  0.7255],
#          [-0.9529, -1.0000, -0.2235,  0.9137,  0.7412],
#          [-1.0000, -1.0000, -0.5686,  0.8510,  0.7882],
#          [-1.0000, -1.0000,  0.8588,  0.7725,  0.7020]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images

# %%
# denormalizing the images in range between 0 and 1
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 9

# %% [markdown]
# # creating a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(fashionmnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# tensor([5, 5, 4, 7, 7, 5, 5, 0, 5, 2, 3, 6, 7, 8, 5, 6, 7, 4, 2, 5, 6, 0, 5, 4,
#         4, 0, 3, 0, 6, 7, 6, 8, 4, 5, 8, 4, 5, 0, 8, 0, 6, 4, 7, 8, 3, 1, 1, 2,
#         1, 0, 2, 7, 0, 6, 3, 7, 4, 3, 3, 4, 0, 8, 8, 0, 4, 3, 2, 7, 0, 6, 6, 7,
#         9, 0, 0, 7, 5, 5, 4, 2, 1, 0, 6, 7, 5, 9, 3, 5, 7, 4, 1, 6, 0, 3, 7, 8,
#         2, 6, 2, 3])

# %% [markdown]
# ## We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784
hidden_size = 256

# %%
# Define a discriminator network 'D' for binary classification with three linear layers and LeakyReLU activations,
# ending with a sigmoid for output normalization.
import torch.nn as nn

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, hidden_size),
    nn.LeakyReLU(0.2),
    nn.Linear(hidden_size, 1),
    nn.Sigmoid())

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/0*6DZve_x3t08PcwYm.JPG" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.

# %%
#Let's move the discriminator model to the chosen device.#
D.to(device);

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %%
latent_size = 64

# %%
# Constructing a generator network 'G' with three linear layers and ReLU activations, outputting through a Tanh layer to match image data dimensions and scale.

G = nn.Sequential(
    nn.Linear(latent_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, hidden_size),
    nn.ReLU(),
    nn.Linear(hidden_size, image_size),
    nn.Tanh())

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is basically random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.

# %%
#Let's move the generator to the chosen device.
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
# Initializing the binary cross-entropy loss function for the discriminator
# and set up its optimizer using Adam with a learning rate of 0.0002.

criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr=0.0002)

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images)
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images)
    d_loss_fake = criterion(outputs, fake_labels)
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad()
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# During discriminator training, real images are processed to compute a loss with target labels set to 1, aiming for the discriminator to correctly classify them as genuine. Subsequently, fake images are generated by the generator, and the discriminator evaluates them, calculating a loss with target labels set to 0, pushing the discriminator to recognize them as generated. The combined losses from real and fake batches are then employed for gradient descent, updating the discriminator's weights via the d_optimizer. Importantly, the generator's weights remain untouched during this process, ensuring its parameters aren't altered during discriminator

# %% [markdown]
# #Generator Training
#
# During generator training, batches of images are produced and fed into the discriminator. The loss is computed by setting target labels to 1 (indicating real images) to incentivize the generator to deceive the discriminator. The obtained loss is then used for gradient descent, adjusting the generator's weights to enhance its ability to generate more realistic images. This process iterates to refine the generator's performance over time.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device)
    g_loss = criterion(D(fake_images), labels)

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# # Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %% [markdown]
# #### Step 2. Train the GAN model to produce images in this new domain.

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break

Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# Additionally, we will create a utility function to save a batch of generated images to disk at the conclusion of each epoch. To observe the evolution of individual generated images throughout the training process, we'll employ a consistent set of input vectors for the generator.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)

# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 100
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()

        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}'
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(),
                          real_score.mean().item(), fake_score.mean().item()))

    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/100], Step [200/600], d_loss: 0.0892, g_loss: 8.5449, D(x): 0.98, D(G(z)): 0.01
# Epoch [0/100], Step [400/600], d_loss: 0.0224, g_loss: 6.4037, D(x): 0.99, D(G(z)): 0.02
# Epoch [0/100], Step [600/600], d_loss: 0.3876, g_loss: 5.8010, D(x): 0.90, D(G(z)): 0.01
# Saving fake_images-0001.png
# Epoch [1/100], Step [200/600], d_loss: 0.0341, g_loss: 6.4355, D(x): 0.98, D(G(z)): 0.01
# Epoch [1/100], Step [400/600], d_loss: 0.0427, g_loss: 5.0475, D(x): 0.99, D(G(z)): 0.03
# Epoch [1/100], Step [600/600], d_loss: 0.0213, g_loss: 6.4001, D(x): 0.99, D(G(z)): 0.01
# Saving fake_images-0002.png
# Epoch [2/100], Step [200/600], d_loss: 0.1087, g_loss: 8.6006, D(x): 0.99, D(G(z)): 0.06
# Epoch [2/100], Step [400/600], d_loss: 0.0396, g_loss: 6.7833, D(x): 0.99, D(G(z)): 0.02
# Epoch [2/100], Step [600/600], d_loss: 0.1727, g_loss: 3.5582, D(x): 0.95, D(G(z)): 0.05
# Saving fake_images-0003.png
# Epoch [3/100], Step [200/600], d_loss: 0.1018, g_loss: 4.2876, D(x): 0.97, D(G(z)): 0.05
# Epoch [3/100], Step [400/600], d_loss: 0.0949, g_loss: 6.2464, D(x): 0.97, D(G(z)): 0.04
# Epoch [3/100], Step [600/600], d_loss: 0.2731, g_loss: 5.3055, D(x): 0.97, D(G(z)): 0.10
# Saving fake_images-0004.png
# Epoch [4/100], Step [200/600], d_loss: 0.1429, g_loss: 4.4892, D(x): 0.94, D(G(z)): 0.04
# Epoch [4/100], Step [400/600], d_loss: 0.1732, g_loss: 4.7802, D(x): 0.98, D(G(z)): 0.10
# Epoch [4/100], Step [600/600], d_loss: 0.2553, g_loss: 5.6996, D(x): 0.92, D(G(z)): 0.03
# Saving fake_images-0005.png
# Epoch [5/100], Step [200/600], d_loss: 0.1705, g_loss: 5.6102, D(x): 0.92, D(G(z)): 0.02
# Epoch [5/100], Step [400/600], d_loss: 0.1340, g_loss: 5.8276, D(x): 0.94, D(G(z)): 0.01
# Epoch [5/100], Step [600/600], d_loss: 0.3960, g_loss: 3.5323, D(x): 0.91, D(G(z)): 0.15
# Saving fake_images-0006.png
# Epoch [6/100], Step [200/600], d_loss: 0.2417, g_loss: 4.5051, D(x): 0.91, D(G(z)): 0.02
# Epoch [6/100], Step [400/600], d_loss: 0.2434, g_loss: 5.5356, D(x): 0.92, D(G(z)): 0.03
# Epoch [6/100], Step [600/600], d_loss: 0.3064, g_loss: 3.9751, D(x): 0.93, D(G(z)): 0.07
# Saving fake_images-0007.png
# Epoch [7/100], Step [200/600], d_loss: 0.1906, g_loss: 3.7406, D(x): 0.96, D(G(z)): 0.10
# Epoch [7/100], Step [400/600], d_loss: 0.1879, g_loss: 4.2125, D(x): 0.92, D(G(z)): 0.05
# Epoch [7/100], Step [600/600], d_loss: 0.2179, g_loss: 4.7649, D(x): 0.96, D(G(z)): 0.10
# Saving fake_images-0008.png
# Epoch [8/100], Step [200/600], d_loss: 0.1217, g_loss: 5.4282, D(x): 0.96, D(G(z)): 0.04
# Epoch [8/100], Step [400/600], d_loss: 0.4346, g_loss: 3.9132, D(x): 0.88, D(G(z)): 0.06
# Epoch [8/100], Step [600/600], d_loss: 0.2123, g_loss: 4.0240, D(x): 0.92, D(G(z)): 0.03
# Saving fake_images-0009.png
# Epoch [9/100], Step [200/600], d_loss: 0.2655, g_loss: 4.5200, D(x): 0.93, D(G(z)): 0.06
# Epoch [9/100], Step [400/600], d_loss: 0.1736, g_loss: 4.9652, D(x): 0.95, D(G(z)): 0.07
# Epoch [9/100], Step [600/600], d_loss: 0.3647, g_loss: 3.5551, D(x): 0.94, D(G(z)): 0.17
# Saving fake_images-0010.png
# Epoch [10/100], Step [200/600], d_loss: 0.3090, g_loss: 4.6988, D(x): 0.90, D(G(z)): 0.04
# Epoch [10/100], Step [400/600], d_loss: 0.3448, g_loss: 5.4111, D(x): 0.88, D(G(z)): 0.03
# Epoch [10/100], Step [600/600], d_loss: 0.2124, g_loss: 6.2434, D(x): 0.93, D(G(z)): 0.05
# Saving fake_images-0011.png
# Epoch [11/100], Step [200/600], d_loss: 0.4045, g_loss: 5.4004, D(x): 0.88, D(G(z)): 0.08
# Epoch [11/100], Step [400/600], d_loss: 0.5263, g_loss: 3.3529, D(x): 0.89, D(G(z)): 0.17
# Epoch [11/100], Step [600/600], d_loss: 0.3100, g_loss: 4.6977, D(x): 0.94, D(G(z)): 0.08
# Saving fake_images-0012.png
# Epoch [12/100], Step [200/600], d_loss: 0.2737, g_loss: 4.1060, D(x): 0.91, D(G(z)): 0.06
# Epoch [12/100], Step [400/600], d_loss: 0.2768, g_loss: 4.4981, D(x): 0.94, D(G(z)): 0.10
# Epoch [12/100], Step [600/600], d_loss: 0.3586, g_loss: 4.1193, D(x): 0.91, D(G(z)): 0.10
# Saving fake_images-0013.png
# Epoch [13/100], Step [200/600], d_loss: 0.2158, g_loss: 3.3147, D(x): 0.95, D(G(z)): 0.11
# Epoch [13/100], Step [400/600], d_loss: 0.3531, g_loss: 3.9768, D(x): 0.92, D(G(z)): 0.13
# Epoch [13/100], Step [600/600], d_loss: 0.1683, g_loss: 3.3618, D(x): 0.94, D(G(z)): 0.07
# Saving fake_images-0014.png
# Epoch [14/100], Step [200/600], d_loss: 0.3117, g_loss: 4.8106, D(x): 0.90, D(G(z)): 0.05
# Epoch [14/100], Step [400/600], d_loss: 0.4345, g_loss: 4.1130, D(x): 0.82, D(G(z)): 0.08
# Epoch [14/100], Step [600/600], d_loss: 0.3189, g_loss: 3.6199, D(x): 0.95, D(G(z)): 0.18
# Saving fake_images-0015.png
# Epoch [15/100], Step [200/600], d_loss: 0.1304, g_loss: 4.0895, D(x): 0.97, D(G(z)): 0.07
# Epoch [15/100], Step [400/600], d_loss: 0.5559, g_loss: 4.7607, D(x): 0.83, D(G(z)): 0.06
# Epoch [15/100], Step [600/600], d_loss: 0.6309, g_loss: 2.8503, D(x): 0.90, D(G(z)): 0.26
# Saving fake_images-0016.png
# Epoch [16/100], Step [200/600], d_loss: 0.4718, g_loss: 3.0206, D(x): 0.89, D(G(z)): 0.16
# Epoch [16/100], Step [400/600], d_loss: 0.3154, g_loss: 3.3947, D(x): 0.89, D(G(z)): 0.07
# Epoch [16/100], Step [600/600], d_loss: 0.5544, g_loss: 4.8398, D(x): 0.84, D(G(z)): 0.07
# Saving fake_images-0017.png
# Epoch [17/100], Step [200/600], d_loss: 0.2987, g_loss: 3.4133, D(x): 0.91, D(G(z)): 0.08
# Epoch [17/100], Step [400/600], d_loss: 0.4090, g_loss: 4.0218, D(x): 0.85, D(G(z)): 0.06
# Epoch [17/100], Step [600/600], d_loss: 0.2865, g_loss: 3.9805, D(x): 0.89, D(G(z)): 0.02
# Saving fake_images-0018.png
# Epoch [18/100], Step [200/600], d_loss: 0.2552, g_loss: 4.3695, D(x): 0.90, D(G(z)): 0.06
# Epoch [18/100], Step [400/600], d_loss: 0.5675, g_loss: 3.2121, D(x): 0.87, D(G(z)): 0.19
# Epoch [18/100], Step [600/600], d_loss: 0.6374, g_loss: 3.7021, D(x): 0.86, D(G(z)): 0.21
# Saving fake_images-0019.png
# Epoch [19/100], Step [200/600], d_loss: 0.3627, g_loss: 3.0868, D(x): 0.90, D(G(z)): 0.16
# Epoch [19/100], Step [400/600], d_loss: 0.3444, g_loss: 3.7078, D(x): 0.89, D(G(z)): 0.11
# Epoch [19/100], Step [600/600], d_loss: 0.4616, g_loss: 2.6227, D(x): 0.94, D(G(z)): 0.23
# Saving fake_images-0020.png
# Epoch [20/100], Step [200/600], d_loss: 0.4179, g_loss: 3.5934, D(x): 0.89, D(G(z)): 0.14
# Epoch [20/100], Step [400/600], d_loss: 0.3655, g_loss: 3.3227, D(x): 0.87, D(G(z)): 0.09
# Epoch [20/100], Step [600/600], d_loss: 0.3512, g_loss: 3.0250, D(x): 0.89, D(G(z)): 0.12
# Saving fake_images-0021.png
# Epoch [21/100], Step [200/600], d_loss: 0.3760, g_loss: 2.7105, D(x): 0.92, D(G(z)): 0.18
# Epoch [21/100], Step [400/600], d_loss: 0.5011, g_loss: 2.8509, D(x): 0.89, D(G(z)): 0.17
# Epoch [21/100], Step [600/600], d_loss: 0.3863, g_loss: 3.3870, D(x): 0.87, D(G(z)): 0.10
# Saving fake_images-0022.png
# Epoch [22/100], Step [200/600], d_loss: 0.5714, g_loss: 2.8308, D(x): 0.79, D(G(z)): 0.09
# Epoch [22/100], Step [400/600], d_loss: 0.4480, g_loss: 3.0972, D(x): 0.87, D(G(z)): 0.14
# Epoch [22/100], Step [600/600], d_loss: 0.6354, g_loss: 3.0332, D(x): 0.82, D(G(z)): 0.18
# Saving fake_images-0023.png
# Epoch [23/100], Step [200/600], d_loss: 0.4752, g_loss: 3.2774, D(x): 0.90, D(G(z)): 0.21
# Epoch [23/100], Step [400/600], d_loss: 0.4144, g_loss: 3.4234, D(x): 0.93, D(G(z)): 0.20
# Epoch [23/100], Step [600/600], d_loss: 0.4101, g_loss: 3.1552, D(x): 0.89, D(G(z)): 0.15
# Saving fake_images-0024.png
# Epoch [24/100], Step [200/600], d_loss: 0.6197, g_loss: 2.1132, D(x): 0.85, D(G(z)): 0.21
# Epoch [24/100], Step [400/600], d_loss: 0.4925, g_loss: 2.9852, D(x): 0.84, D(G(z)): 0.11
# Epoch [24/100], Step [600/600], d_loss: 0.5598, g_loss: 2.6644, D(x): 0.87, D(G(z)): 0.14
# Saving fake_images-0025.png
# Epoch [25/100], Step [200/600], d_loss: 0.3588, g_loss: 3.1903, D(x): 0.88, D(G(z)): 0.10
# Epoch [25/100], Step [400/600], d_loss: 0.5417, g_loss: 2.3839, D(x): 0.87, D(G(z)): 0.18
# Epoch [25/100], Step [600/600], d_loss: 0.5150, g_loss: 3.0657, D(x): 0.86, D(G(z)): 0.16
# Saving fake_images-0026.png
# Epoch [26/100], Step [200/600], d_loss: 0.6472, g_loss: 3.9045, D(x): 0.77, D(G(z)): 0.08
# Epoch [26/100], Step [400/600], d_loss: 0.5012, g_loss: 3.3320, D(x): 0.83, D(G(z)): 0.11
# Epoch [26/100], Step [600/600], d_loss: 0.5638, g_loss: 2.4585, D(x): 0.89, D(G(z)): 0.22
# Saving fake_images-0027.png
# Epoch [27/100], Step [200/600], d_loss: 0.3761, g_loss: 3.7151, D(x): 0.91, D(G(z)): 0.16
# Epoch [27/100], Step [400/600], d_loss: 0.4523, g_loss: 2.5597, D(x): 0.83, D(G(z)): 0.11
# Epoch [27/100], Step [600/600], d_loss: 0.6981, g_loss: 2.8825, D(x): 0.80, D(G(z)): 0.14
# Saving fake_images-0028.png
# Epoch [28/100], Step [200/600], d_loss: 0.6381, g_loss: 2.2692, D(x): 0.85, D(G(z)): 0.19
# Epoch [28/100], Step [400/600], d_loss: 0.4043, g_loss: 3.0522, D(x): 0.89, D(G(z)): 0.14
# Epoch [28/100], Step [600/600], d_loss: 0.5183, g_loss: 2.7317, D(x): 0.85, D(G(z)): 0.17
# Saving fake_images-0029.png
# Epoch [29/100], Step [200/600], d_loss: 0.6141, g_loss: 3.0791, D(x): 0.83, D(G(z)): 0.14
# Epoch [29/100], Step [400/600], d_loss: 0.5636, g_loss: 3.0462, D(x): 0.81, D(G(z)): 0.13
# Epoch [29/100], Step [600/600], d_loss: 0.6089, g_loss: 3.2723, D(x): 0.78, D(G(z)): 0.11
# Saving fake_images-0030.png
# Epoch [30/100], Step [200/600], d_loss: 0.2928, g_loss: 3.4361, D(x): 0.89, D(G(z)): 0.09
# Epoch [30/100], Step [400/600], d_loss: 0.5280, g_loss: 2.8515, D(x): 0.79, D(G(z)): 0.07
# Epoch [30/100], Step [600/600], d_loss: 0.8007, g_loss: 1.7026, D(x): 0.80, D(G(z)): 0.25
# Saving fake_images-0031.png
# Epoch [31/100], Step [200/600], d_loss: 0.6855, g_loss: 2.5296, D(x): 0.79, D(G(z)): 0.14
# Epoch [31/100], Step [400/600], d_loss: 0.6547, g_loss: 2.5441, D(x): 0.80, D(G(z)): 0.18
# Epoch [31/100], Step [600/600], d_loss: 0.5253, g_loss: 2.5601, D(x): 0.83, D(G(z)): 0.18
# Saving fake_images-0032.png
# Epoch [32/100], Step [200/600], d_loss: 0.7052, g_loss: 2.2022, D(x): 0.75, D(G(z)): 0.16
# Epoch [32/100], Step [400/600], d_loss: 0.5675, g_loss: 2.2764, D(x): 0.82, D(G(z)): 0.20
# Epoch [32/100], Step [600/600], d_loss: 0.6944, g_loss: 3.1540, D(x): 0.79, D(G(z)): 0.17
# Saving fake_images-0033.png
# Epoch [33/100], Step [200/600], d_loss: 0.6677, g_loss: 2.7835, D(x): 0.83, D(G(z)): 0.15
# Epoch [33/100], Step [400/600], d_loss: 0.8553, g_loss: 2.3334, D(x): 0.77, D(G(z)): 0.25
# Epoch [33/100], Step [600/600], d_loss: 0.5247, g_loss: 2.9935, D(x): 0.82, D(G(z)): 0.16
# Saving fake_images-0034.png
# Epoch [34/100], Step [200/600], d_loss: 0.4413, g_loss: 3.0794, D(x): 0.84, D(G(z)): 0.13
# Epoch [34/100], Step [400/600], d_loss: 0.4131, g_loss: 2.9383, D(x): 0.85, D(G(z)): 0.13
# Epoch [34/100], Step [600/600], d_loss: 0.4667, g_loss: 2.3948, D(x): 0.87, D(G(z)): 0.17
# Saving fake_images-0035.png
# Epoch [35/100], Step [200/600], d_loss: 0.4961, g_loss: 2.6220, D(x): 0.83, D(G(z)): 0.16
# Epoch [35/100], Step [400/600], d_loss: 0.6921, g_loss: 2.3063, D(x): 0.79, D(G(z)): 0.17
# Epoch [35/100], Step [600/600], d_loss: 0.7234, g_loss: 2.4368, D(x): 0.82, D(G(z)): 0.25
# Saving fake_images-0036.png
# Epoch [36/100], Step [200/600], d_loss: 0.5016, g_loss: 2.8920, D(x): 0.81, D(G(z)): 0.12
# Epoch [36/100], Step [400/600], d_loss: 0.7024, g_loss: 2.3710, D(x): 0.79, D(G(z)): 0.16
# Epoch [36/100], Step [600/600], d_loss: 0.7033, g_loss: 2.3827, D(x): 0.80, D(G(z)): 0.18
# Saving fake_images-0037.png
# Epoch [37/100], Step [200/600], d_loss: 0.6786, g_loss: 2.7223, D(x): 0.75, D(G(z)): 0.14
# Epoch [37/100], Step [400/600], d_loss: 0.5742, g_loss: 2.0662, D(x): 0.82, D(G(z)): 0.18
# Epoch [37/100], Step [600/600], d_loss: 0.5557, g_loss: 2.5684, D(x): 0.80, D(G(z)): 0.16
# Saving fake_images-0038.png
# Epoch [38/100], Step [200/600], d_loss: 0.5134, g_loss: 2.8913, D(x): 0.79, D(G(z)): 0.13
# Epoch [38/100], Step [400/600], d_loss: 0.7805, g_loss: 2.1081, D(x): 0.83, D(G(z)): 0.30
# Epoch [38/100], Step [600/600], d_loss: 0.6334, g_loss: 2.3696, D(x): 0.88, D(G(z)): 0.30
# Saving fake_images-0039.png
# Epoch [39/100], Step [200/600], d_loss: 0.3101, g_loss: 3.2898, D(x): 0.93, D(G(z)): 0.16
# Epoch [39/100], Step [400/600], d_loss: 0.7110, g_loss: 2.4056, D(x): 0.81, D(G(z)): 0.26
# Epoch [39/100], Step [600/600], d_loss: 0.5924, g_loss: 3.1917, D(x): 0.80, D(G(z)): 0.11
# Saving fake_images-0040.png
# Epoch [40/100], Step [200/600], d_loss: 0.5147, g_loss: 2.4760, D(x): 0.84, D(G(z)): 0.19
# Epoch [40/100], Step [400/600], d_loss: 0.5994, g_loss: 2.5342, D(x): 0.80, D(G(z)): 0.19
# Epoch [40/100], Step [600/600], d_loss: 0.5558, g_loss: 3.0321, D(x): 0.82, D(G(z)): 0.19
# Saving fake_images-0041.png
# Epoch [41/100], Step [200/600], d_loss: 0.4507, g_loss: 2.9626, D(x): 0.86, D(G(z)): 0.15
# Epoch [41/100], Step [400/600], d_loss: 0.8332, g_loss: 2.5032, D(x): 0.82, D(G(z)): 0.23
# Epoch [41/100], Step [600/600], d_loss: 0.5686, g_loss: 3.2807, D(x): 0.80, D(G(z)): 0.13
# Saving fake_images-0042.png
# Epoch [42/100], Step [200/600], d_loss: 0.6787, g_loss: 2.5572, D(x): 0.78, D(G(z)): 0.19
# Epoch [42/100], Step [400/600], d_loss: 0.7420, g_loss: 2.2980, D(x): 0.75, D(G(z)): 0.17
# Epoch [42/100], Step [600/600], d_loss: 0.6195, g_loss: 3.0059, D(x): 0.85, D(G(z)): 0.22
# Saving fake_images-0043.png
# Epoch [43/100], Step [200/600], d_loss: 0.6319, g_loss: 2.4366, D(x): 0.85, D(G(z)): 0.23
# Epoch [43/100], Step [400/600], d_loss: 0.5198, g_loss: 2.9848, D(x): 0.85, D(G(z)): 0.19
# Epoch [43/100], Step [600/600], d_loss: 0.7462, g_loss: 1.9257, D(x): 0.80, D(G(z)): 0.22
# Saving fake_images-0044.png
# Epoch [44/100], Step [200/600], d_loss: 0.6718, g_loss: 2.9340, D(x): 0.80, D(G(z)): 0.18
# Epoch [44/100], Step [400/600], d_loss: 0.4086, g_loss: 2.5594, D(x): 0.88, D(G(z)): 0.17
# Epoch [44/100], Step [600/600], d_loss: 0.7995, g_loss: 2.5384, D(x): 0.69, D(G(z)): 0.18
# Saving fake_images-0045.png
# Epoch [45/100], Step [200/600], d_loss: 0.4958, g_loss: 2.9875, D(x): 0.82, D(G(z)): 0.15
# Epoch [45/100], Step [400/600], d_loss: 0.7449, g_loss: 2.5332, D(x): 0.80, D(G(z)): 0.23
# Epoch [45/100], Step [600/600], d_loss: 0.6850, g_loss: 2.3429, D(x): 0.79, D(G(z)): 0.21
# Saving fake_images-0046.png
# Epoch [46/100], Step [200/600], d_loss: 0.6678, g_loss: 2.3994, D(x): 0.82, D(G(z)): 0.24
# Epoch [46/100], Step [400/600], d_loss: 0.5909, g_loss: 2.7885, D(x): 0.80, D(G(z)): 0.19
# Epoch [46/100], Step [600/600], d_loss: 0.5740, g_loss: 2.7552, D(x): 0.86, D(G(z)): 0.19
# Saving fake_images-0047.png
# Epoch [47/100], Step [200/600], d_loss: 0.6526, g_loss: 2.2629, D(x): 0.82, D(G(z)): 0.20
# Epoch [47/100], Step [400/600], d_loss: 0.6714, g_loss: 2.3019, D(x): 0.78, D(G(z)): 0.20
# Epoch [47/100], Step [600/600], d_loss: 0.8154, g_loss: 2.0322, D(x): 0.81, D(G(z)): 0.31
# Saving fake_images-0048.png
# Epoch [48/100], Step [200/600], d_loss: 0.5200, g_loss: 2.3222, D(x): 0.92, D(G(z)): 0.27
# Epoch [48/100], Step [400/600], d_loss: 0.7158, g_loss: 1.9853, D(x): 0.83, D(G(z)): 0.29
# Epoch [48/100], Step [600/600], d_loss: 0.8167, g_loss: 2.1489, D(x): 0.78, D(G(z)): 0.26
# Saving fake_images-0049.png
# Epoch [49/100], Step [200/600], d_loss: 0.7616, g_loss: 2.0161, D(x): 0.82, D(G(z)): 0.28
# Epoch [49/100], Step [400/600], d_loss: 0.8445, g_loss: 2.5871, D(x): 0.76, D(G(z)): 0.25
# Epoch [49/100], Step [600/600], d_loss: 0.6925, g_loss: 1.7988, D(x): 0.84, D(G(z)): 0.30
# Saving fake_images-0050.png
# Epoch [50/100], Step [200/600], d_loss: 0.5885, g_loss: 2.5191, D(x): 0.81, D(G(z)): 0.19
# Epoch [50/100], Step [400/600], d_loss: 0.7733, g_loss: 2.1506, D(x): 0.73, D(G(z)): 0.20
# Epoch [50/100], Step [600/600], d_loss: 0.6435, g_loss: 2.9887, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0051.png
# Epoch [51/100], Step [200/600], d_loss: 0.5101, g_loss: 2.4370, D(x): 0.81, D(G(z)): 0.13
# Epoch [51/100], Step [400/600], d_loss: 0.7092, g_loss: 2.6489, D(x): 0.77, D(G(z)): 0.13
# Epoch [51/100], Step [600/600], d_loss: 0.6715, g_loss: 2.2516, D(x): 0.81, D(G(z)): 0.22
# Saving fake_images-0052.png
# Epoch [52/100], Step [200/600], d_loss: 0.6371, g_loss: 2.4966, D(x): 0.79, D(G(z)): 0.20
# Epoch [52/100], Step [400/600], d_loss: 0.8228, g_loss: 1.9154, D(x): 0.82, D(G(z)): 0.32
# Epoch [52/100], Step [600/600], d_loss: 0.7703, g_loss: 2.5558, D(x): 0.77, D(G(z)): 0.24
# Saving fake_images-0053.png
# Epoch [53/100], Step [200/600], d_loss: 0.7288, g_loss: 2.4832, D(x): 0.79, D(G(z)): 0.24
# Epoch [53/100], Step [400/600], d_loss: 1.0242, g_loss: 2.4725, D(x): 0.67, D(G(z)): 0.21
# Epoch [53/100], Step [600/600], d_loss: 0.6463, g_loss: 2.0019, D(x): 0.78, D(G(z)): 0.21
# Saving fake_images-0054.png
# Epoch [54/100], Step [200/600], d_loss: 0.6816, g_loss: 2.2253, D(x): 0.78, D(G(z)): 0.22
# Epoch [54/100], Step [400/600], d_loss: 0.5980, g_loss: 2.2800, D(x): 0.79, D(G(z)): 0.17
# Epoch [54/100], Step [600/600], d_loss: 0.5638, g_loss: 2.2261, D(x): 0.85, D(G(z)): 0.24
# Saving fake_images-0055.png
# Epoch [55/100], Step [200/600], d_loss: 0.7412, g_loss: 2.5711, D(x): 0.73, D(G(z)): 0.18
# Epoch [55/100], Step [400/600], d_loss: 0.8504, g_loss: 2.0084, D(x): 0.79, D(G(z)): 0.27
# Epoch [55/100], Step [600/600], d_loss: 0.8914, g_loss: 2.1585, D(x): 0.78, D(G(z)): 0.31
# Saving fake_images-0056.png
# Epoch [56/100], Step [200/600], d_loss: 0.6635, g_loss: 2.2436, D(x): 0.78, D(G(z)): 0.23
# Epoch [56/100], Step [400/600], d_loss: 0.5338, g_loss: 2.3057, D(x): 0.79, D(G(z)): 0.17
# Epoch [56/100], Step [600/600], d_loss: 0.7348, g_loss: 2.0002, D(x): 0.77, D(G(z)): 0.24
# Saving fake_images-0057.png
# Epoch [57/100], Step [200/600], d_loss: 0.9079, g_loss: 2.3317, D(x): 0.71, D(G(z)): 0.22
# Epoch [57/100], Step [400/600], d_loss: 0.6690, g_loss: 2.2746, D(x): 0.76, D(G(z)): 0.21
# Epoch [57/100], Step [600/600], d_loss: 0.7084, g_loss: 2.1274, D(x): 0.77, D(G(z)): 0.22
# Saving fake_images-0058.png
# Epoch [58/100], Step [200/600], d_loss: 0.8546, g_loss: 2.5640, D(x): 0.73, D(G(z)): 0.22
# Epoch [58/100], Step [400/600], d_loss: 0.8181, g_loss: 1.8561, D(x): 0.79, D(G(z)): 0.29
# Epoch [58/100], Step [600/600], d_loss: 0.8873, g_loss: 1.8998, D(x): 0.74, D(G(z)): 0.29
# Saving fake_images-0059.png
# Epoch [59/100], Step [200/600], d_loss: 0.6914, g_loss: 2.1857, D(x): 0.77, D(G(z)): 0.21
# Epoch [59/100], Step [400/600], d_loss: 1.0065, g_loss: 1.7293, D(x): 0.68, D(G(z)): 0.21
# Epoch [59/100], Step [600/600], d_loss: 0.7808, g_loss: 1.8197, D(x): 0.80, D(G(z)): 0.28
# Saving fake_images-0060.png
# Epoch [60/100], Step [200/600], d_loss: 0.8989, g_loss: 1.8159, D(x): 0.72, D(G(z)): 0.25
# Epoch [60/100], Step [400/600], d_loss: 0.7497, g_loss: 2.2338, D(x): 0.78, D(G(z)): 0.26
# Epoch [60/100], Step [600/600], d_loss: 0.7745, g_loss: 2.2629, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0061.png
# Epoch [61/100], Step [200/600], d_loss: 0.5882, g_loss: 2.5112, D(x): 0.82, D(G(z)): 0.22
# Epoch [61/100], Step [400/600], d_loss: 0.5735, g_loss: 1.8533, D(x): 0.87, D(G(z)): 0.28
# Epoch [61/100], Step [600/600], d_loss: 0.7255, g_loss: 2.0719, D(x): 0.77, D(G(z)): 0.23
# Saving fake_images-0062.png
# Epoch [62/100], Step [200/600], d_loss: 0.7713, g_loss: 2.2066, D(x): 0.79, D(G(z)): 0.30
# Epoch [62/100], Step [400/600], d_loss: 0.6832, g_loss: 2.1930, D(x): 0.81, D(G(z)): 0.26
# Epoch [62/100], Step [600/600], d_loss: 0.9240, g_loss: 2.0280, D(x): 0.75, D(G(z)): 0.32
# Saving fake_images-0063.png
# Epoch [63/100], Step [200/600], d_loss: 0.8999, g_loss: 2.4869, D(x): 0.71, D(G(z)): 0.26
# Epoch [63/100], Step [400/600], d_loss: 0.8277, g_loss: 2.5244, D(x): 0.69, D(G(z)): 0.18
# Epoch [63/100], Step [600/600], d_loss: 0.8107, g_loss: 1.8139, D(x): 0.77, D(G(z)): 0.25
# Saving fake_images-0064.png
# Epoch [64/100], Step [200/600], d_loss: 1.1402, g_loss: 1.8853, D(x): 0.70, D(G(z)): 0.29
# Epoch [64/100], Step [400/600], d_loss: 0.4424, g_loss: 3.0295, D(x): 0.83, D(G(z)): 0.16
# Epoch [64/100], Step [600/600], d_loss: 0.6076, g_loss: 1.6191, D(x): 0.82, D(G(z)): 0.26
# Saving fake_images-0065.png
# Epoch [65/100], Step [200/600], d_loss: 0.8066, g_loss: 2.2103, D(x): 0.66, D(G(z)): 0.17
# Epoch [65/100], Step [400/600], d_loss: 0.6829, g_loss: 1.9859, D(x): 0.82, D(G(z)): 0.27
# Epoch [65/100], Step [600/600], d_loss: 0.8188, g_loss: 2.1334, D(x): 0.78, D(G(z)): 0.30
# Saving fake_images-0066.png
# Epoch [66/100], Step [200/600], d_loss: 0.9256, g_loss: 1.5612, D(x): 0.72, D(G(z)): 0.29
# Epoch [66/100], Step [400/600], d_loss: 0.9706, g_loss: 2.0094, D(x): 0.73, D(G(z)): 0.30
# Epoch [66/100], Step [600/600], d_loss: 0.8987, g_loss: 2.0788, D(x): 0.70, D(G(z)): 0.23
# Saving fake_images-0067.png
# Epoch [67/100], Step [200/600], d_loss: 0.6466, g_loss: 2.4192, D(x): 0.74, D(G(z)): 0.19
# Epoch [67/100], Step [400/600], d_loss: 0.7470, g_loss: 2.0553, D(x): 0.76, D(G(z)): 0.20
# Epoch [67/100], Step [600/600], d_loss: 0.8892, g_loss: 2.0736, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0068.png
# Epoch [68/100], Step [200/600], d_loss: 0.7587, g_loss: 2.2916, D(x): 0.72, D(G(z)): 0.22
# Epoch [68/100], Step [400/600], d_loss: 1.0063, g_loss: 1.9763, D(x): 0.74, D(G(z)): 0.33
# Epoch [68/100], Step [600/600], d_loss: 1.0008, g_loss: 1.6491, D(x): 0.73, D(G(z)): 0.34
# Saving fake_images-0069.png
# Epoch [69/100], Step [200/600], d_loss: 0.6891, g_loss: 2.7103, D(x): 0.77, D(G(z)): 0.23
# Epoch [69/100], Step [400/600], d_loss: 1.0729, g_loss: 1.7702, D(x): 0.67, D(G(z)): 0.30
# Epoch [69/100], Step [600/600], d_loss: 0.8213, g_loss: 2.2485, D(x): 0.75, D(G(z)): 0.25
# Saving fake_images-0070.png
# Epoch [70/100], Step [200/600], d_loss: 0.8112, g_loss: 1.9411, D(x): 0.77, D(G(z)): 0.29
# Epoch [70/100], Step [400/600], d_loss: 0.7530, g_loss: 2.1548, D(x): 0.75, D(G(z)): 0.23
# Epoch [70/100], Step [600/600], d_loss: 0.7406, g_loss: 2.4227, D(x): 0.73, D(G(z)): 0.19
# Saving fake_images-0071.png
# Epoch [71/100], Step [200/600], d_loss: 0.9365, g_loss: 2.7745, D(x): 0.70, D(G(z)): 0.24
# Epoch [71/100], Step [400/600], d_loss: 0.9868, g_loss: 1.9207, D(x): 0.82, D(G(z)): 0.42
# Epoch [71/100], Step [600/600], d_loss: 0.7175, g_loss: 2.2372, D(x): 0.82, D(G(z)): 0.28
# Saving fake_images-0072.png
# Epoch [72/100], Step [200/600], d_loss: 0.8421, g_loss: 1.9305, D(x): 0.69, D(G(z)): 0.23
# Epoch [72/100], Step [400/600], d_loss: 0.9188, g_loss: 1.6819, D(x): 0.73, D(G(z)): 0.33
# Epoch [72/100], Step [600/600], d_loss: 0.9167, g_loss: 2.2187, D(x): 0.68, D(G(z)): 0.21
# Saving fake_images-0073.png
# Epoch [73/100], Step [200/600], d_loss: 0.6746, g_loss: 2.5920, D(x): 0.72, D(G(z)): 0.17
# Epoch [73/100], Step [400/600], d_loss: 0.8291, g_loss: 2.8694, D(x): 0.71, D(G(z)): 0.18
# Epoch [73/100], Step [600/600], d_loss: 0.7951, g_loss: 1.3063, D(x): 0.78, D(G(z)): 0.28
# Saving fake_images-0074.png
# Epoch [74/100], Step [200/600], d_loss: 1.0169, g_loss: 2.0742, D(x): 0.69, D(G(z)): 0.28
# Epoch [74/100], Step [400/600], d_loss: 0.5691, g_loss: 2.6506, D(x): 0.80, D(G(z)): 0.20
# Epoch [74/100], Step [600/600], d_loss: 0.7407, g_loss: 2.2017, D(x): 0.70, D(G(z)): 0.19
# Saving fake_images-0075.png
# Epoch [75/100], Step [200/600], d_loss: 1.0110, g_loss: 2.3926, D(x): 0.77, D(G(z)): 0.30
# Epoch [75/100], Step [400/600], d_loss: 0.9481, g_loss: 1.7949, D(x): 0.68, D(G(z)): 0.23
# Epoch [75/100], Step [600/600], d_loss: 0.8220, g_loss: 1.9899, D(x): 0.70, D(G(z)): 0.22
# Saving fake_images-0076.png
# Epoch [76/100], Step [200/600], d_loss: 0.7856, g_loss: 1.9541, D(x): 0.73, D(G(z)): 0.19
# Epoch [76/100], Step [400/600], d_loss: 1.0069, g_loss: 2.0887, D(x): 0.70, D(G(z)): 0.28
# Epoch [76/100], Step [600/600], d_loss: 1.0707, g_loss: 1.8358, D(x): 0.66, D(G(z)): 0.28
# Saving fake_images-0077.png
# Epoch [77/100], Step [200/600], d_loss: 0.5302, g_loss: 2.1289, D(x): 0.86, D(G(z)): 0.24
# Epoch [77/100], Step [400/600], d_loss: 1.1365, g_loss: 1.2983, D(x): 0.74, D(G(z)): 0.39
# Epoch [77/100], Step [600/600], d_loss: 0.7581, g_loss: 1.3420, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0078.png
# Epoch [78/100], Step [200/600], d_loss: 0.7750, g_loss: 2.0548, D(x): 0.79, D(G(z)): 0.27
# Epoch [78/100], Step [400/600], d_loss: 0.8612, g_loss: 1.9155, D(x): 0.71, D(G(z)): 0.24
# Epoch [78/100], Step [600/600], d_loss: 0.7254, g_loss: 2.3528, D(x): 0.71, D(G(z)): 0.19
# Saving fake_images-0079.png
# Epoch [79/100], Step [200/600], d_loss: 0.8310, g_loss: 1.5947, D(x): 0.73, D(G(z)): 0.25
# Epoch [79/100], Step [400/600], d_loss: 1.0577, g_loss: 1.5869, D(x): 0.74, D(G(z)): 0.31
# Epoch [79/100], Step [600/600], d_loss: 0.8105, g_loss: 2.3681, D(x): 0.73, D(G(z)): 0.25
# Saving fake_images-0080.png
# Epoch [80/100], Step [200/600], d_loss: 1.1231, g_loss: 1.4989, D(x): 0.79, D(G(z)): 0.38
# Epoch [80/100], Step [400/600], d_loss: 0.7194, g_loss: 2.3344, D(x): 0.73, D(G(z)): 0.20
# Epoch [80/100], Step [600/600], d_loss: 0.8843, g_loss: 1.7380, D(x): 0.75, D(G(z)): 0.29
# Saving fake_images-0081.png
# Epoch [81/100], Step [200/600], d_loss: 0.5844, g_loss: 1.8984, D(x): 0.80, D(G(z)): 0.23
# Epoch [81/100], Step [400/600], d_loss: 0.7376, g_loss: 2.1935, D(x): 0.78, D(G(z)): 0.26
# Epoch [81/100], Step [600/600], d_loss: 0.8609, g_loss: 2.5228, D(x): 0.71, D(G(z)): 0.21
# Saving fake_images-0082.png
# Epoch [82/100], Step [200/600], d_loss: 0.8372, g_loss: 1.9031, D(x): 0.76, D(G(z)): 0.29
# Epoch [82/100], Step [400/600], d_loss: 0.8001, g_loss: 2.3275, D(x): 0.73, D(G(z)): 0.22
# Epoch [82/100], Step [600/600], d_loss: 0.8577, g_loss: 1.5436, D(x): 0.78, D(G(z)): 0.31
# Saving fake_images-0083.png
# Epoch [83/100], Step [200/600], d_loss: 0.8922, g_loss: 1.5549, D(x): 0.78, D(G(z)): 0.37
# Epoch [83/100], Step [400/600], d_loss: 0.9618, g_loss: 1.9449, D(x): 0.70, D(G(z)): 0.29
# Epoch [83/100], Step [600/600], d_loss: 0.8514, g_loss: 1.6503, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0084.png
# Epoch [84/100], Step [200/600], d_loss: 0.8326, g_loss: 1.9641, D(x): 0.75, D(G(z)): 0.25
# Epoch [84/100], Step [400/600], d_loss: 0.8615, g_loss: 1.9704, D(x): 0.74, D(G(z)): 0.28
# Epoch [84/100], Step [600/600], d_loss: 0.7153, g_loss: 2.0651, D(x): 0.73, D(G(z)): 0.19
# Saving fake_images-0085.png
# Epoch [85/100], Step [200/600], d_loss: 0.8901, g_loss: 1.7423, D(x): 0.67, D(G(z)): 0.23
# Epoch [85/100], Step [400/600], d_loss: 1.0759, g_loss: 1.5179, D(x): 0.67, D(G(z)): 0.27
# Epoch [85/100], Step [600/600], d_loss: 0.7446, g_loss: 1.9885, D(x): 0.69, D(G(z)): 0.19
# Saving fake_images-0086.png
# Epoch [86/100], Step [200/600], d_loss: 1.0014, g_loss: 2.1599, D(x): 0.69, D(G(z)): 0.25
# Epoch [86/100], Step [400/600], d_loss: 0.6542, g_loss: 2.2117, D(x): 0.80, D(G(z)): 0.23
# Epoch [86/100], Step [600/600], d_loss: 1.0631, g_loss: 2.1340, D(x): 0.67, D(G(z)): 0.30
# Saving fake_images-0087.png
# Epoch [87/100], Step [200/600], d_loss: 1.0179, g_loss: 1.7563, D(x): 0.76, D(G(z)): 0.35
# Epoch [87/100], Step [400/600], d_loss: 0.9047, g_loss: 1.9066, D(x): 0.72, D(G(z)): 0.32
# Epoch [87/100], Step [600/600], d_loss: 0.9253, g_loss: 1.7580, D(x): 0.69, D(G(z)): 0.23
# Saving fake_images-0088.png
# Epoch [88/100], Step [200/600], d_loss: 0.8767, g_loss: 1.9892, D(x): 0.71, D(G(z)): 0.24
# Epoch [88/100], Step [400/600], d_loss: 0.7209, g_loss: 2.1896, D(x): 0.76, D(G(z)): 0.25
# Epoch [88/100], Step [600/600], d_loss: 1.0338, g_loss: 1.6562, D(x): 0.60, D(G(z)): 0.24
# Saving fake_images-0089.png
# Epoch [89/100], Step [200/600], d_loss: 0.8031, g_loss: 2.1251, D(x): 0.69, D(G(z)): 0.20
# Epoch [89/100], Step [400/600], d_loss: 0.8538, g_loss: 1.7185, D(x): 0.74, D(G(z)): 0.31
# Epoch [89/100], Step [600/600], d_loss: 1.1159, g_loss: 1.4358, D(x): 0.63, D(G(z)): 0.30
# Saving fake_images-0090.png
# Epoch [90/100], Step [200/600], d_loss: 0.9986, g_loss: 1.4933, D(x): 0.63, D(G(z)): 0.25
# Epoch [90/100], Step [400/600], d_loss: 0.7380, g_loss: 1.6745, D(x): 0.75, D(G(z)): 0.26
# Epoch [90/100], Step [600/600], d_loss: 0.8765, g_loss: 1.6034, D(x): 0.74, D(G(z)): 0.31
# Saving fake_images-0091.png
# Epoch [91/100], Step [200/600], d_loss: 0.9068, g_loss: 1.8492, D(x): 0.73, D(G(z)): 0.29
# Epoch [91/100], Step [400/600], d_loss: 0.8780, g_loss: 1.7959, D(x): 0.69, D(G(z)): 0.23
# Epoch [91/100], Step [600/600], d_loss: 0.7162, g_loss: 1.9417, D(x): 0.76, D(G(z)): 0.24
# Saving fake_images-0092.png
# Epoch [92/100], Step [200/600], d_loss: 0.6403, g_loss: 1.9625, D(x): 0.77, D(G(z)): 0.23
# Epoch [92/100], Step [400/600], d_loss: 0.9582, g_loss: 1.9355, D(x): 0.66, D(G(z)): 0.20
# Epoch [92/100], Step [600/600], d_loss: 0.8874, g_loss: 1.7356, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0093.png
# Epoch [93/100], Step [200/600], d_loss: 0.7847, g_loss: 1.9038, D(x): 0.77, D(G(z)): 0.26
# Epoch [93/100], Step [400/600], d_loss: 0.7932, g_loss: 1.9124, D(x): 0.74, D(G(z)): 0.27
# Epoch [93/100], Step [600/600], d_loss: 0.8225, g_loss: 1.9945, D(x): 0.74, D(G(z)): 0.26
# Saving fake_images-0094.png
# Epoch [94/100], Step [200/600], d_loss: 0.7695, g_loss: 1.6995, D(x): 0.78, D(G(z)): 0.28
# Epoch [94/100], Step [400/600], d_loss: 0.9022, g_loss: 2.0145, D(x): 0.68, D(G(z)): 0.22
# Epoch [94/100], Step [600/600], d_loss: 0.9125, g_loss: 1.9366, D(x): 0.71, D(G(z)): 0.30
# Saving fake_images-0095.png
# Epoch [95/100], Step [200/600], d_loss: 1.1293, g_loss: 1.8612, D(x): 0.58, D(G(z)): 0.23
# Epoch [95/100], Step [400/600], d_loss: 0.7322, g_loss: 1.7953, D(x): 0.78, D(G(z)): 0.26
# Epoch [95/100], Step [600/600], d_loss: 0.8566, g_loss: 1.5707, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0096.png
# Epoch [96/100], Step [200/600], d_loss: 0.9581, g_loss: 1.8245, D(x): 0.75, D(G(z)): 0.38
# Epoch [96/100], Step [400/600], d_loss: 1.0472, g_loss: 1.7499, D(x): 0.66, D(G(z)): 0.28
# Epoch [96/100], Step [600/600], d_loss: 0.7328, g_loss: 2.0924, D(x): 0.79, D(G(z)): 0.26
# Saving fake_images-0097.png
# Epoch [97/100], Step [200/600], d_loss: 0.7433, g_loss: 2.3938, D(x): 0.76, D(G(z)): 0.25
# Epoch [97/100], Step [400/600], d_loss: 0.8824, g_loss: 1.9844, D(x): 0.71, D(G(z)): 0.26
# Epoch [97/100], Step [600/600], d_loss: 0.7693, g_loss: 2.0467, D(x): 0.72, D(G(z)): 0.25
# Saving fake_images-0098.png
# Epoch [98/100], Step [200/600], d_loss: 0.7296, g_loss: 2.0790, D(x): 0.70, D(G(z)): 0.20
# Epoch [98/100], Step [400/600], d_loss: 1.0163, g_loss: 1.5959, D(x): 0.69, D(G(z)): 0.31
# Epoch [98/100], Step [600/600], d_loss: 0.6849, g_loss: 2.0843, D(x): 0.79, D(G(z)): 0.24
# Saving fake_images-0099.png
# Epoch [99/100], Step [200/600], d_loss: 0.8028, g_loss: 1.8666, D(x): 0.72, D(G(z)): 0.27
# Epoch [99/100], Step [400/600], d_loss: 0.5638, g_loss: 2.4540, D(x): 0.79, D(G(z)): 0.20
# Epoch [99/100], Step [600/600], d_loss: 0.8808, g_loss: 1.6039, D(x): 0.69, D(G(z)): 0.26
# Saving fake_images-0100.png
# CPU times: user 25min 56s, sys: 10.5 s, total: 26min 6s
# Wall time: 25min 59s

# %% [markdown]
# ##Step3. Attempt to save and display at least 3 samples produced from your GAN model. Describe and discuss any difficulties faced in this process.

# %% [markdown]
# difficulties : During initial epochs, images generated by the GAN might appear blurry or lack sharpness. This is a common issue as the model refines its ability to generate high-quality images over subsequent epochs.
#
# In the early epochs, the generator may struggle to produce diverse images, leading to a phenomenon known as mode collapse, where it generates a limited set of outputs, lacking variety.
#
# and finally GANs often exhibit a slow training process, requiring numerous epochs to reach convergence. This gradual pace can be attributed to the intricate dynamics between the generator and discriminator, making training more time-consuming compared to other neural network architectures.

# %% [markdown]
# Here's how the generated images look, after the 10th, 50th, 100th epochs of training.

# %%
Image('./samples/fake_images-0020.png')

# %%
Image('./samples/fake_images-0040.png')

# %%
Image('./samples/fake_images-0060.png')

# %%
Image('./samples/fake_images-0080.png')

# %%
Image('./samples/fake_images-0100.png')

# %% [markdown]
# #### Step 4. Save the model weights in the folder to be used later.

# %%
# Save the model checkpoints
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %%
folder_path = './fake_images_folder'

# %%
torch.save(G.state_dict(), os.path.join(folder_path,'generator_model.pth'))
torch.save(D.state_dict(), os.path.join(folder_path,'discriminator_model.pth'))

# %% [markdown]
# Displaying the iteration of epochs and improvement in the gnerator throught pictures

# %%
import cv2
import os
from IPython.display import FileLink

vid_fname = 'gans_training.avi'

files = [os.path.join(sample_dir, f) for f in os.listdir(sample_dir) if 'fake_images' in f]
files.sort()

out = cv2.VideoWriter(vid_fname,cv2.VideoWriter_fourcc(*'MP4V'), 8, (302,302))
[out.write(cv2.imread(fname)) for fname in files]
out.release()
FileLink('gans_training.avi')
# Out:
# /content/gans_training.avi

# %% [markdown]
# #### Losses of Discriminator and Generator

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %% [markdown]
# as from the above graph for generator the loss is decreasing as increase witht the number of epochs which shows the good sign that is its learning properly from the loss fucntion and the discriminator loss is increasing propotionally

# %% [markdown]
# #### Real Score Vs Fake Score

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# The graph emphasizes the real and fake scores, illustrating the discriminator's proficiency in distinguishing between authentic and generated images. The real score demonstrates a consistently high and stable performance, indicating reliable recognition of real images. In contrast, the fake score initiates at a low point and shows an ascending trajectory, signifying the generator's incremental success in producing images that increasingly resemble real ones. This trend reflects the generator's improving ability to deceive the discriminator throughout the training process.

# %%
# Load the generator model
G.load_state_dict(torch.load(os.path.join(folder_path, 'generator_model.pth')))
G.eval()  # Set the model to evaluation mode

# Load the discriminator model
D.load_state_dict(torch.load(os.path.join(folder_path, 'discriminator_model.pth')))
D.eval()  # Set the model to evaluation mode
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# #### Step 6: Re-train the GAN model to see if you can improve.

# %%
import torch.optim as optim

# Define the RMSprop optimizers for both networks
d_optimizer = optim.RMSprop(D.parameters(), lr=0.0001)
g_optimizer = optim.RMSprop(G.parameters(), lr=0.0001)

# Set the number of epochs to continue training and the starting epoch
num_additional_epochs = 50
start_epoch = 101
end_epoch = start_epoch + num_additional_epochs

# Calculate the total number of steps in each epoch
total_step = len(data_loader)

# Lists to keep track of losses and scores
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

# Training loop
for epoch in range(start_epoch, end_epoch):
    for i, (images, _) in enumerate(data_loader):
        # Reshape and load batch to device
        images = images.reshape(batch_size, -1).to(device)

        # Train the discriminator
        d_loss, real_score, fake_score = train_discriminator(images)
        # Train the generator
        g_loss, fake_images = train_generator()

        # Log the losses and scores every 200 steps
        if (i + 1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print(f'Epoch [{epoch}/{end_epoch - 1}], Step [{i + 1}/{total_step}], d_loss: {d_loss.item():.4f}, g_loss: {g_loss.item():.4f}, D(x): {real_score.mean().item():.2f}, D(G(z)): {fake_score.mean().item():.2f}')

    # Save generated images for inspection (implement save_fake_images function as needed)
    save_fake_images(epoch)

# Function implementations for train_discriminator and train_generator are assumed to be provided
# Out:
# Epoch [101/150], Step [200/600], d_loss: 1.0405, g_loss: 1.1762, D(x): 0.64, D(G(z)): 0.35
# Epoch [101/150], Step [400/600], d_loss: 1.0722, g_loss: 0.9906, D(x): 0.63, D(G(z)): 0.34
# Epoch [101/150], Step [600/600], d_loss: 1.2270, g_loss: 0.6692, D(x): 0.48, D(G(z)): 0.24
# Saving fake_images-0101.png
# Epoch [102/150], Step [200/600], d_loss: 1.2155, g_loss: 0.8392, D(x): 0.55, D(G(z)): 0.35
# Epoch [102/150], Step [400/600], d_loss: 1.1107, g_loss: 1.1516, D(x): 0.64, D(G(z)): 0.41
# Epoch [102/150], Step [600/600], d_loss: 1.2380, g_loss: 0.8739, D(x): 0.51, D(G(z)): 0.29
# Saving fake_images-0102.png
# Epoch [103/150], Step [200/600], d_loss: 1.0610, g_loss: 1.1242, D(x): 0.69, D(G(z)): 0.42
# Epoch [103/150], Step [400/600], d_loss: 1.0936, g_loss: 0.8680, D(x): 0.57, D(G(z)): 0.32
# Epoch [103/150], Step [600/600], d_loss: 1.1693, g_loss: 1.1673, D(x): 0.68, D(G(z)): 0.48
# Saving fake_images-0103.png
# Epoch [104/150], Step [200/600], d_loss: 1.1301, g_loss: 1.0649, D(x): 0.62, D(G(z)): 0.39
# Epoch [104/150], Step [400/600], d_loss: 1.0578, g_loss: 1.1994, D(x): 0.64, D(G(z)): 0.39
# Epoch [104/150], Step [600/600], d_loss: 1.2734, g_loss: 1.2390, D(x): 0.59, D(G(z)): 0.41
# Saving fake_images-0104.png
# Epoch [105/150], Step [200/600], d_loss: 1.1419, g_loss: 0.8660, D(x): 0.56, D(G(z)): 0.31
# Epoch [105/150], Step [400/600], d_loss: 1.1414, g_loss: 1.1751, D(x): 0.65, D(G(z)): 0.44
# Epoch [105/150], Step [600/600], d_loss: 1.2033, g_loss: 1.1021, D(x): 0.65, D(G(z)): 0.44
# Saving fake_images-0105.png
# Epoch [106/150], Step [200/600], d_loss: 1.0739, g_loss: 1.3273, D(x): 0.75, D(G(z)): 0.49
# Epoch [106/150], Step [400/600], d_loss: 1.1565, g_loss: 0.8645, D(x): 0.56, D(G(z)): 0.33
# Epoch [106/150], Step [600/600], d_loss: 1.1879, g_loss: 0.9312, D(x): 0.57, D(G(z)): 0.39
# Saving fake_images-0106.png
# Epoch [107/150], Step [200/600], d_loss: 1.1392, g_loss: 0.9700, D(x): 0.58, D(G(z)): 0.35
# Epoch [107/150], Step [400/600], d_loss: 1.1334, g_loss: 1.0879, D(x): 0.61, D(G(z)): 0.39
# Epoch [107/150], Step [600/600], d_loss: 1.1122, g_loss: 1.2006, D(x): 0.67, D(G(z)): 0.45
# Saving fake_images-0107.png
# Epoch [108/150], Step [200/600], d_loss: 1.1069, g_loss: 1.0944, D(x): 0.63, D(G(z)): 0.38
# Epoch [108/150], Step [400/600], d_loss: 1.1755, g_loss: 1.1073, D(x): 0.62, D(G(z)): 0.42
# Epoch [108/150], Step [600/600], d_loss: 1.1251, g_loss: 1.2824, D(x): 0.67, D(G(z)): 0.44
# Saving fake_images-0108.png
# Epoch [109/150], Step [200/600], d_loss: 1.2231, g_loss: 1.2945, D(x): 0.72, D(G(z)): 0.54
# Epoch [109/150], Step [400/600], d_loss: 1.0989, g_loss: 1.2187, D(x): 0.64, D(G(z)): 0.40
# Epoch [109/150], Step [600/600], d_loss: 1.1404, g_loss: 0.9123, D(x): 0.57, D(G(z)): 0.34
# Saving fake_images-0109.png
# Epoch [110/150], Step [200/600], d_loss: 1.1788, g_loss: 1.5128, D(x): 0.71, D(G(z)): 0.51
# Epoch [110/150], Step [400/600], d_loss: 1.1869, g_loss: 1.4626, D(x): 0.72, D(G(z)): 0.51
# Epoch [110/150], Step [600/600], d_loss: 1.0589, g_loss: 1.0150, D(x): 0.64, D(G(z)): 0.39
# Saving fake_images-0110.png
# Epoch [111/150], Step [200/600], d_loss: 1.0629, g_loss: 1.1131, D(x): 0.65, D(G(z)): 0.40
# Epoch [111/150], Step [400/600], d_loss: 1.1974, g_loss: 1.1501, D(x): 0.62, D(G(z)): 0.42
# Epoch [111/150], Step [600/600], d_loss: 1.1417, g_loss: 1.3610, D(x): 0.68, D(G(z)): 0.46
# Saving fake_images-0111.png
# Epoch [112/150], Step [200/600], d_loss: 1.1198, g_loss: 1.0431, D(x): 0.63, D(G(z)): 0.40
# Epoch [112/150], Step [400/600], d_loss: 1.0648, g_loss: 1.0474, D(x): 0.60, D(G(z)): 0.34
# Epoch [112/150], Step [600/600], d_loss: 1.1639, g_loss: 0.8307, D(x): 0.52, D(G(z)): 0.29
# Saving fake_images-0112.png
# Epoch [113/150], Step [200/600], d_loss: 1.0837, g_loss: 1.0201, D(x): 0.59, D(G(z)): 0.34
# Epoch [113/150], Step [400/600], d_loss: 1.1898, g_loss: 0.8025, D(x): 0.49, D(G(z)): 0.29
# Epoch [113/150], Step [600/600], d_loss: 1.1295, g_loss: 0.9750, D(x): 0.59, D(G(z)): 0.38
# Saving fake_images-0113.png
# Epoch [114/150], Step [200/600], d_loss: 1.0682, g_loss: 1.1217, D(x): 0.63, D(G(z)): 0.38
# Epoch [114/150], Step [400/600], d_loss: 1.1704, g_loss: 1.1415, D(x): 0.60, D(G(z)): 0.39
# Epoch [114/150], Step [600/600], d_loss: 1.1177, g_loss: 0.9964, D(x): 0.59, D(G(z)): 0.36
# Saving fake_images-0114.png
# Epoch [115/150], Step [200/600], d_loss: 1.2130, g_loss: 0.9268, D(x): 0.54, D(G(z)): 0.36
# Epoch [115/150], Step [400/600], d_loss: 1.2175, g_loss: 0.9820, D(x): 0.57, D(G(z)): 0.40
# Epoch [115/150], Step [600/600], d_loss: 1.1684, g_loss: 1.0367, D(x): 0.60, D(G(z)): 0.40
# Saving fake_images-0115.png
# Epoch [116/150], Step [200/600], d_loss: 1.1757, g_loss: 1.1156, D(x): 0.63, D(G(z)): 0.43
# Epoch [116/150], Step [400/600], d_loss: 1.1268, g_loss: 1.0150, D(x): 0.59, D(G(z)): 0.37
# Epoch [116/150], Step [600/600], d_loss: 1.1240, g_loss: 1.2525, D(x): 0.69, D(G(z)): 0.47
# Saving fake_images-0116.png
# Epoch [117/150], Step [200/600], d_loss: 1.0857, g_loss: 1.1855, D(x): 0.69, D(G(z)): 0.45
# Epoch [117/150], Step [400/600], d_loss: 1.1633, g_loss: 1.4031, D(x): 0.69, D(G(z)): 0.48
# Epoch [117/150], Step [600/600], d_loss: 1.1300, g_loss: 1.1680, D(x): 0.64, D(G(z)): 0.41
# Saving fake_images-0117.png
# Epoch [118/150], Step [200/600], d_loss: 1.1670, g_loss: 0.9335, D(x): 0.55, D(G(z)): 0.34
# Epoch [118/150], Step [400/600], d_loss: 1.0624, g_loss: 1.1810, D(x): 0.68, D(G(z)): 0.44
# Epoch [118/150], Step [600/600], d_loss: 1.1164, g_loss: 0.8861, D(x): 0.57, D(G(z)): 0.36
# Saving fake_images-0118.png
# Epoch [119/150], Step [200/600], d_loss: 1.1832, g_loss: 0.9936, D(x): 0.58, D(G(z)): 0.37
# Epoch [119/150], Step [400/600], d_loss: 1.0729, g_loss: 0.9976, D(x): 0.60, D(G(z)): 0.37
# Epoch [119/150], Step [600/600], d_loss: 1.1515, g_loss: 0.9418, D(x): 0.58, D(G(z)): 0.37
# Saving fake_images-0119.png
# Epoch [120/150], Step [200/600], d_loss: 1.1466, g_loss: 1.1500, D(x): 0.66, D(G(z)): 0.43
# Epoch [120/150], Step [400/600], d_loss: 1.1118, g_loss: 1.0537, D(x): 0.64, D(G(z)): 0.43
# Epoch [120/150], Step [600/600], d_loss: 1.1645, g_loss: 1.3500, D(x): 0.69, D(G(z)): 0.49
# Saving fake_images-0120.png
# Epoch [121/150], Step [200/600], d_loss: 1.1037, g_loss: 0.8816, D(x): 0.56, D(G(z)): 0.34
# Epoch [121/150], Step [400/600], d_loss: 1.0359, g_loss: 0.9843, D(x): 0.63, D(G(z)): 0.37
# Epoch [121/150], Step [600/600], d_loss: 1.1604, g_loss: 1.0820, D(x): 0.61, D(G(z)): 0.42
# Saving fake_images-0121.png
# Epoch [122/150], Step [200/600], d_loss: 1.2217, g_loss: 1.1323, D(x): 0.64, D(G(z)): 0.48
# Epoch [122/150], Step [400/600], d_loss: 1.1260, g_loss: 1.0358, D(x): 0.61, D(G(z)): 0.38
# Epoch [122/150], Step [600/600], d_loss: 1.1685, g_loss: 0.9092, D(x): 0.58, D(G(z)): 0.38
# Saving fake_images-0122.png
# Epoch [123/150], Step [200/600], d_loss: 1.1835, g_loss: 1.1251, D(x): 0.63, D(G(z)): 0.44
# Epoch [123/150], Step [400/600], d_loss: 1.1188, g_loss: 0.9707, D(x): 0.59, D(G(z)): 0.37
# Epoch [123/150], Step [600/600], d_loss: 1.0800, g_loss: 1.0574, D(x): 0.64, D(G(z)): 0.41
# Saving fake_images-0123.png
# Epoch [124/150], Step [200/600], d_loss: 1.0959, g_loss: 0.7587, D(x): 0.56, D(G(z)): 0.32
# Epoch [124/150], Step [400/600], d_loss: 1.1506, g_loss: 0.9243, D(x): 0.59, D(G(z)): 0.41
# Epoch [124/150], Step [600/600], d_loss: 1.0626, g_loss: 1.0360, D(x): 0.63, D(G(z)): 0.38
# Saving fake_images-0124.png
# Epoch [125/150], Step [200/600], d_loss: 1.0603, g_loss: 1.3242, D(x): 0.68, D(G(z)): 0.43
# Epoch [125/150], Step [400/600], d_loss: 1.1057, g_loss: 0.9803, D(x): 0.62, D(G(z)): 0.40
# Epoch [125/150], Step [600/600], d_loss: 1.1803, g_loss: 1.0374, D(x): 0.60, D(G(z)): 0.39
# Saving fake_images-0125.png
# Epoch [126/150], Step [200/600], d_loss: 1.0459, g_loss: 0.8997, D(x): 0.59, D(G(z)): 0.35
# Epoch [126/150], Step [400/600], d_loss: 1.0719, g_loss: 0.8373, D(x): 0.53, D(G(z)): 0.27
# Epoch [126/150], Step [600/600], d_loss: 1.1224, g_loss: 1.0821, D(x): 0.59, D(G(z)): 0.38
# Saving fake_images-0126.png
# Epoch [127/150], Step [200/600], d_loss: 1.0993, g_loss: 1.1579, D(x): 0.63, D(G(z)): 0.39
# Epoch [127/150], Step [400/600], d_loss: 1.1780, g_loss: 1.1898, D(x): 0.62, D(G(z)): 0.43
# Epoch [127/150], Step [600/600], d_loss: 1.2208, g_loss: 0.7445, D(x): 0.50, D(G(z)): 0.30
# Saving fake_images-0127.png
# Epoch [128/150], Step [200/600], d_loss: 1.0563, g_loss: 1.0014, D(x): 0.61, D(G(z)): 0.36
# Epoch [128/150], Step [400/600], d_loss: 1.1675, g_loss: 1.0297, D(x): 0.58, D(G(z)): 0.38
# Epoch [128/150], Step [600/600], d_loss: 1.0499, g_loss: 0.9820, D(x): 0.58, D(G(z)): 0.30
# Saving fake_images-0128.png
# Epoch [129/150], Step [200/600], d_loss: 1.2132, g_loss: 1.3034, D(x): 0.69, D(G(z)): 0.51
# Epoch [129/150], Step [400/600], d_loss: 1.2122, g_loss: 1.3812, D(x): 0.71, D(G(z)): 0.52
# Epoch [129/150], Step [600/600], d_loss: 1.2146, g_loss: 0.8988, D(x): 0.54, D(G(z)): 0.37
# Saving fake_images-0129.png
# Epoch [130/150], Step [200/600], d_loss: 1.0653, g_loss: 0.9288, D(x): 0.61, D(G(z)): 0.36
# Epoch [130/150], Step [400/600], d_loss: 1.0536, g_loss: 1.0292, D(x): 0.63, D(G(z)): 0.36
# Epoch [130/150], Step [600/600], d_loss: 1.1307, g_loss: 1.0734, D(x): 0.62, D(G(z)): 0.42
# Saving fake_images-0130.png
# Epoch [131/150], Step [200/600], d_loss: 1.1844, g_loss: 0.9679, D(x): 0.61, D(G(z)): 0.42
# Epoch [131/150], Step [400/600], d_loss: 1.0690, g_loss: 1.0178, D(x): 0.65, D(G(z)): 0.42
# Epoch [131/150], Step [600/600], d_loss: 1.0671, g_loss: 1.1999, D(x): 0.66, D(G(z)): 0.42
# Saving fake_images-0131.png
# Epoch [132/150], Step [200/600], d_loss: 1.0191, g_loss: 1.0468, D(x): 0.62, D(G(z)): 0.35
# Epoch [132/150], Step [400/600], d_loss: 1.1412, g_loss: 0.8616, D(x): 0.55, D(G(z)): 0.34
# Epoch [132/150], Step [600/600], d_loss: 1.1590, g_loss: 1.1216, D(x): 0.64, D(G(z)): 0.43
# Saving fake_images-0132.png
# Epoch [133/150], Step [200/600], d_loss: 1.1984, g_loss: 1.2059, D(x): 0.63, D(G(z)): 0.44
# Epoch [133/150], Step [400/600], d_loss: 1.1072, g_loss: 1.0171, D(x): 0.56, D(G(z)): 0.34
# Epoch [133/150], Step [600/600], d_loss: 1.1604, g_loss: 0.9215, D(x): 0.57, D(G(z)): 0.35
# Saving fake_images-0133.png
# Epoch [134/150], Step [200/600], d_loss: 1.2411, g_loss: 1.1198, D(x): 0.65, D(G(z)): 0.47
# Epoch [134/150], Step [400/600], d_loss: 1.1624, g_loss: 1.1144, D(x): 0.66, D(G(z)): 0.47
# Epoch [134/150], Step [600/600], d_loss: 1.0392, g_loss: 1.0537, D(x): 0.65, D(G(z)): 0.39
# Saving fake_images-0134.png
# Epoch [135/150], Step [200/600], d_loss: 1.1471, g_loss: 1.2974, D(x): 0.69, D(G(z)): 0.47
# Epoch [135/150], Step [400/600], d_loss: 1.1244, g_loss: 0.9556, D(x): 0.59, D(G(z)): 0.37
# Epoch [135/150], Step [600/600], d_loss: 1.1220, g_loss: 1.0922, D(x): 0.64, D(G(z)): 0.41
# Saving fake_images-0135.png
# Epoch [136/150], Step [200/600], d_loss: 1.1908, g_loss: 0.8581, D(x): 0.55, D(G(z)): 0.36
# Epoch [136/150], Step [400/600], d_loss: 1.1562, g_loss: 1.1677, D(x): 0.69, D(G(z)): 0.49
# Epoch [136/150], Step [600/600], d_loss: 1.0331, g_loss: 0.9719, D(x): 0.60, D(G(z)): 0.34
# Saving fake_images-0136.png
# Epoch [137/150], Step [200/600], d_loss: 1.0889, g_loss: 1.0452, D(x): 0.60, D(G(z)): 0.37
# Epoch [137/150], Step [400/600], d_loss: 1.1376, g_loss: 0.9450, D(x): 0.59, D(G(z)): 0.39
# Epoch [137/150], Step [600/600], d_loss: 1.3506, g_loss: 0.5788, D(x): 0.41, D(G(z)): 0.26
# Saving fake_images-0137.png
# Epoch [138/150], Step [200/600], d_loss: 1.1476, g_loss: 0.9826, D(x): 0.58, D(G(z)): 0.39
# Epoch [138/150], Step [400/600], d_loss: 1.1618, g_loss: 1.0739, D(x): 0.64, D(G(z)): 0.45
# Epoch [138/150], Step [600/600], d_loss: 1.0528, g_loss: 0.9543, D(x): 0.63, D(G(z)): 0.39
# Saving fake_images-0138.png
# Epoch [139/150], Step [200/600], d_loss: 1.1434, g_loss: 1.0382, D(x): 0.60, D(G(z)): 0.41
# Epoch [139/150], Step [400/600], d_loss: 1.0634, g_loss: 1.0412, D(x): 0.64, D(G(z)): 0.39
# Epoch [139/150], Step [600/600], d_loss: 1.1277, g_loss: 0.8331, D(x): 0.57, D(G(z)): 0.36
# Saving fake_images-0139.png
# Epoch [140/150], Step [200/600], d_loss: 1.1433, g_loss: 0.9697, D(x): 0.59, D(G(z)): 0.37
# Epoch [140/150], Step [400/600], d_loss: 1.1527, g_loss: 1.1369, D(x): 0.62, D(G(z)): 0.41
# Epoch [140/150], Step [600/600], d_loss: 1.1167, g_loss: 0.9241, D(x): 0.57, D(G(z)): 0.34
# Saving fake_images-0140.png
# Epoch [141/150], Step [200/600], d_loss: 1.2442, g_loss: 1.5244, D(x): 0.71, D(G(z)): 0.54
# Epoch [141/150], Step [400/600], d_loss: 1.1597, g_loss: 1.0945, D(x): 0.66, D(G(z)): 0.46
# Epoch [141/150], Step [600/600], d_loss: 1.0793, g_loss: 1.0451, D(x): 0.59, D(G(z)): 0.35
# Saving fake_images-0141.png
# Epoch [142/150], Step [200/600], d_loss: 1.1741, g_loss: 0.8919, D(x): 0.56, D(G(z)): 0.35
# Epoch [142/150], Step [400/600], d_loss: 1.0212, g_loss: 1.0605, D(x): 0.67, D(G(z)): 0.40
# Epoch [142/150], Step [600/600], d_loss: 1.1373, g_loss: 0.9225, D(x): 0.59, D(G(z)): 0.37
# Saving fake_images-0142.png
# Epoch [143/150], Step [200/600], d_loss: 1.1305, g_loss: 1.0353, D(x): 0.59, D(G(z)): 0.36
# Epoch [143/150], Step [400/600], d_loss: 1.1973, g_loss: 1.0102, D(x): 0.57, D(G(z)): 0.40
# Epoch [143/150], Step [600/600], d_loss: 1.1216, g_loss: 0.9863, D(x): 0.57, D(G(z)): 0.34
# Saving fake_images-0143.png
# Epoch [144/150], Step [200/600], d_loss: 1.1726, g_loss: 1.0597, D(x): 0.62, D(G(z)): 0.43
# Epoch [144/150], Step [400/600], d_loss: 1.0836, g_loss: 0.9368, D(x): 0.58, D(G(z)): 0.35
# Epoch [144/150], Step [600/600], d_loss: 1.1557, g_loss: 1.1384, D(x): 0.64, D(G(z)): 0.44
# Saving fake_images-0144.png
# Epoch [145/150], Step [200/600], d_loss: 1.0608, g_loss: 0.8951, D(x): 0.59, D(G(z)): 0.34
# Epoch [145/150], Step [400/600], d_loss: 1.1107, g_loss: 0.9186, D(x): 0.63, D(G(z)): 0.42
# Epoch [145/150], Step [600/600], d_loss: 1.2240, g_loss: 1.0962, D(x): 0.61, D(G(z)): 0.44
# Saving fake_images-0145.png
# Epoch [146/150], Step [200/600], d_loss: 1.1511, g_loss: 1.1243, D(x): 0.66, D(G(z)): 0.45
# Epoch [146/150], Step [400/600], d_loss: 1.1455, g_loss: 1.0557, D(x): 0.63, D(G(z)): 0.43
# Epoch [146/150], Step [600/600], d_loss: 1.1374, g_loss: 1.2302, D(x): 0.66, D(G(z)): 0.45
# Saving fake_images-0146.png
# Epoch [147/150], Step [200/600], d_loss: 1.2028, g_loss: 1.0501, D(x): 0.59, D(G(z)): 0.41
# Epoch [147/150], Step [400/600], d_loss: 1.1678, g_loss: 1.0197, D(x): 0.58, D(G(z)): 0.38
# Epoch [147/150], Step [600/600], d_loss: 1.1700, g_loss: 1.0647, D(x): 0.64, D(G(z)): 0.45
# Saving fake_images-0147.png
# Epoch [148/150], Step [200/600], d_loss: 1.1403, g_loss: 0.9481, D(x): 0.59, D(G(z)): 0.37
# Epoch [148/150], Step [400/600], d_loss: 1.0917, g_loss: 1.0854, D(x): 0.61, D(G(z)): 0.38
# Epoch [148/150], Step [600/600], d_loss: 1.1456, g_loss: 1.1714, D(x): 0.61, D(G(z)): 0.41
# Saving fake_images-0148.png
# Epoch [149/150], Step [200/600], d_loss: 1.1208, g_loss: 1.1812, D(x): 0.61, D(G(z)): 0.39
# Epoch [149/150], Step [400/600], d_loss: 1.2073, g_loss: 1.1053, D(x): 0.63, D(G(z)): 0.46
# Epoch [149/150], Step [600/600], d_loss: 1.0742, g_loss: 0.8348, D(x): 0.57, D(G(z)): 0.32
# Saving fake_images-0149.png
# Epoch [150/150], Step [200/600], d_loss: 1.1908, g_loss: 0.8325, D(x): 0.54, D(G(z)): 0.35
# Epoch [150/150], Step [400/600], d_loss: 1.2220, g_loss: 1.2015, D(x): 0.64, D(G(z)): 0.47
# Epoch [150/150], Step [600/600], d_loss: 1.1004, g_loss: 1.0337, D(x): 0.57, D(G(z)): 0.36
# Saving fake_images-0150.png

# %% [markdown]
# ## Saving the model weights

# %%
torch.save(G.state_dict(), os.path.join(folder_path,'retrained_generator_model.pth'))
torch.save(D.state_dict(), os.path.join(folder_path,'retrained_discriminator_model.pth'))

# %% [markdown]
# ##Loading the model weights

# %%
# Load the generator model
G.load_state_dict(torch.load(os.path.join(folder_path, 'retrained_generator_model.pth')))
G.eval()  # Set the model to evaluation mode

# Load the discriminator model
D.load_state_dict(torch.load(os.path.join(folder_path, 'retrained_discriminator_model.pth')))
D.eval()  # Set the model to evaluation mode
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# Here's how the generated images look, after the 110,120,130,140,150 epochs of training.

# %%
Image('./samples/fake_images-0110.png')

# %%
Image('./samples/fake_images-0120.png')

# %%
Image('./samples/fake_images-0130.png')

# %%
Image('./samples/fake_images-0140.png')

# %%
Image('./samples/fake_images-0150.png')

# %% [markdown]
# ## Losses of Discriminator and Generator

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %% [markdown]
# #### Real Score Vs Fake Score

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# Github: https://github.com/shashankchintu99/semester3-projects/tree/main/deeplearning/assignments
